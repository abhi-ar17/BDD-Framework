# %% [markdown]
# <a href="https://colab.research.google.com/github/abhi-ar17/BDD-Framework/blob/master/DBMS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install Django

# %%
# !unzip employee_database\ \(4\).zip

# %%
pip install djongo

# %%
pip install pymongo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pymongo in /usr/local/lib/python3.8/dist-packages (4.3.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.8/dist-packages (from pymongo) (2.3.0)

# %%
# !django-admin startproject myproject
# !django-admin startproject employee_database
# !cd employee_database && python manage.py startapp PersonalData

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip

# %%
# !./ngrok authtoken 2MEzmBMheTKErpD1YMYY5nybALk_52hzkR9ufnSPj9PABqDtc
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
# !pip install pyngrok
from pyngrok import ngrok

# Start ngrok tunnel
public_url = ngrok.connect(port=80,http_tunnel=False)
print(public_url)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.9/dist-packages (5.2.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from pyngrok) (6.0)
# NgrokTunnel: "http://3d00-130-211-241-8.ngrok.io" -> "http://localhost:80"

# %%
# !cd employee_database && python manage.py makemigrations PersonalData
# Out:
# No changes detected in app 'PersonalData'

# %%
# !cd employee_database && python manage.py migrate
# Out:
# Operations to perform:
#   Apply all migrations: PersonalData, admin, auth, contenttypes, sessions
# Running migrations:
#   No migrations to apply.

# %%
# !cd employee_database && python manage.py runserver 127.0.0.1:80
# Out:
# [18/Mar/2023 19:09:44] "GET /employee/create/ HTTP/1.1" 200 2622
# [18/Mar/2023 19:10:15] "POST /employee/create/ HTTP/1.1" 200 2779
# /content/employee_database/PersonalData/models.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:10:41
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# /content/employee_database/PersonalData/models.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:11:29
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# /content/employee_database/PersonalData/forms.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# Exception in thread django-main-thread:
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.9/threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/django/utils/autoreload.py", line 64, in wrapper
#     fn(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/django/core/management/commands/runserver.py", line 134, in inner_run
#     self.check(display_num_errors=True)
#   File "/usr/local/lib/python3.9/dist-packages/django/core/management/base.py", line 475, in check
#     all_issues = checks.run_checks(
#   File "/usr/local/lib/python3.9/dist-packages/django/core/checks/registry.py", line 88, in run_checks
#     new_errors = check(app_configs=app_configs, databases=databases)
#   File "/usr/local/lib/python3.9/dist-packages/django/core/checks/urls.py", line 14, in check_url_config
#     return check_resolver(resolver)
#   File "/usr/local/lib/python3.9/dist-packages/django/core/checks/urls.py", line 24, in check_resolver
#     return check_method()
#   File "/usr/local/lib/python3.9/dist-packages/django/urls/resolvers.py", line 494, in check
#     for pattern in self.url_patterns:
#   File "/usr/local/lib/python3.9/dist-packages/django/utils/functional.py", line 57, in __get__
#     res = instance.__dict__[self.name] = self.func(instance)
#   File "/usr/local/lib/python3.9/dist-packages/django/urls/resolvers.py", line 715, in url_patterns
#     patterns = getattr(self.urlconf_module, "urlpatterns", self.urlconf_module)
#   File "/usr/local/lib/python3.9/dist-packages/django/utils/functional.py", line 57, in __get__
#     res = instance.__dict__[self.name] = self.func(instance)
#   File "/usr/local/lib/python3.9/dist-packages/django/urls/resolvers.py", line 708, in urlconf_module
#     return import_module(self.urlconf_name)
#   File "/usr/lib/python3.9/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/content/employee_database/employee_database/urls.py", line 18, in <module>
#     from PersonalData.views import employee_create
#   File "/content/employee_database/PersonalData/views.py", line 3, in <module>
#     from .forms import EmployeeForm
#   File "/content/employee_database/PersonalData/forms.py", line 14, in <module>
#     class EmployeeForm(forms.ModelForm):
#   File "/content/employee_database/PersonalData/forms.py", line 20, in EmployeeForm
#     class Meta:
#   File "/content/employee_database/PersonalData/forms.py", line 24, in Meta
#     'dob': widgets.DateInput(attrs={'type': 'date'})
# NameError: name 'widgets' is not defined
# /content/employee_database/PersonalData/forms.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# Exception in thread django-main-thread:
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.9/threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/django/utils/autoreload.py", line 64, in wrapper
#     fn(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/django/core/management/commands/runserver.py", line 134, in inner_run
#     self.check(display_num_errors=True)
#   File "/usr/local/lib/python3.9/dist-packages/django/core/management/base.py", line 475, in check
#     all_issues = checks.run_checks(
#   File "/usr/local/lib/python3.9/dist-packages/django/core/checks/registry.py", line 88, in run_checks
#     new_errors = check(app_configs=app_configs, databases=databases)
#   File "/usr/local/lib/python3.9/dist-packages/django/core/checks/urls.py", line 14, in check_url_config
#     return check_resolver(resolver)
#   File "/usr/local/lib/python3.9/dist-packages/django/core/checks/urls.py", line 24, in check_resolver
#     return check_method()
#   File "/usr/local/lib/python3.9/dist-packages/django/urls/resolvers.py", line 494, in check
#     for pattern in self.url_patterns:
#   File "/usr/local/lib/python3.9/dist-packages/django/utils/functional.py", line 57, in __get__
#     res = instance.__dict__[self.name] = self.func(instance)
#   File "/usr/local/lib/python3.9/dist-packages/django/urls/resolvers.py", line 715, in url_patterns
#     patterns = getattr(self.urlconf_module, "urlpatterns", self.urlconf_module)
#   File "/usr/local/lib/python3.9/dist-packages/django/utils/functional.py", line 57, in __get__
#     res = instance.__dict__[self.name] = self.func(instance)
#   File "/usr/local/lib/python3.9/dist-packages/django/urls/resolvers.py", line 708, in urlconf_module
#     return import_module(self.urlconf_name)
#   File "/usr/lib/python3.9/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/content/employee_database/employee_database/urls.py", line 18, in <module>
#     from PersonalData.views import employee_create
#   File "/content/employee_database/PersonalData/views.py", line 3, in <module>
#     from .forms import EmployeeForm
#   File "/content/employee_database/PersonalData/forms.py", line 14, in <module>
#     class EmployeeForm(forms.ModelForm):
#   File "/content/employee_database/PersonalData/forms.py", line 20, in EmployeeForm
#     class Meta:
#   File "/content/employee_database/PersonalData/forms.py", line 24, in Meta
#     'dob': widgets.DateInput(attrs={'type': 'date'})
# NameError: name 'widgets' is not defined
# /content/employee_database/PersonalData/forms.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:12:02
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# /content/employee_database/PersonalData/forms.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:12:06
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# [18/Mar/2023 19:12:10] "POST /employee/create/ HTTP/1.1" 200 2779
# Internal Server Error: /employee/create/
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/django/core/handlers/exception.py", line 56, in inner
#     response = get_response(request)
#   File "/usr/local/lib/python3.9/dist-packages/django/core/handlers/base.py", line 197, in _get_response
#     response = wrapped_callback(request, *callback_args, **callback_kwargs)
#   File "/content/employee_database/PersonalData/views.py", line 28, in employee_create
#     primaryContact=form.cleaned_data['primaryContact'],
# KeyError: 'primaryContact'
# [18/Mar/2023 19:12:24] "POST /employee/create/ HTTP/1.1" 500 72983
# [18/Mar/2023 19:13:04] "GET /employee/create/ HTTP/1.1" 200 2622
# Internal Server Error: /employee/create/
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/django/core/handlers/exception.py", line 56, in inner
#     response = get_response(request)
#   File "/usr/local/lib/python3.9/dist-packages/django/core/handlers/base.py", line 197, in _get_response
#     response = wrapped_callback(request, *callback_args, **callback_kwargs)
#   File "/content/employee_database/PersonalData/views.py", line 28, in employee_create
#     primaryContact=form.cleaned_data['primaryContact'],
# KeyError: 'primaryContact'
# [18/Mar/2023 19:13:40] "POST /employee/create/ HTTP/1.1" 500 72949
# /content/employee_database/PersonalData/views.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:14:33
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# /content/employee_database/PersonalData/views.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:14:35
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# /content/employee_database/PersonalData/views.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:14:38
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# Internal Server Error: /employee/create/
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/django/core/handlers/exception.py", line 56, in inner
#     response = get_response(request)
#   File "/usr/local/lib/python3.9/dist-packages/django/core/handlers/base.py", line 197, in _get_response
#     response = wrapped_callback(request, *callback_args, **callback_kwargs)
#   File "/content/employee_database/PersonalData/views.py", line 39, in employee_create
#     employee.save()
# NameError: name 'employee' is not defined
# [18/Mar/2023 19:14:39] "POST /employee/create/ HTTP/1.1" 500 72928
# Internal Server Error: /employee/create/
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/django/core/handlers/exception.py", line 56, in inner
#     response = get_response(request)
#   File "/usr/local/lib/python3.9/dist-packages/django/core/handlers/base.py", line 197, in _get_response
#     response = wrapped_callback(request, *callback_args, **callback_kwargs)
#   File "/content/employee_database/PersonalData/views.py", line 39, in employee_create
#     employee.save()
# NameError: name 'employee' is not defined
# [18/Mar/2023 19:14:46] "POST /employee/create/ HTTP/1.1" 500 72928
# /content/employee_database/PersonalData/views.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:14:59
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# [18/Mar/2023 19:15:01] "GET /employee/create HTTP/1.1" 301 0
# [18/Mar/2023 19:15:01] "GET /employee/create/ HTTP/1.1" 200 2622
# Internal Server Error: /employee/create/
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/django/core/handlers/exception.py", line 56, in inner
#     response = get_response(request)
#   File "/usr/local/lib/python3.9/dist-packages/django/core/handlers/base.py", line 197, in _get_response
#     response = wrapped_callback(request, *callback_args, **callback_kwargs)
#   File "/content/employee_database/PersonalData/views.py", line 39, in employee_create
#     employee.save()
# NameError: name 'employee' is not defined
# [18/Mar/2023 19:15:21] "POST /employee/create/ HTTP/1.1" 500 72880
# /content/employee_database/PersonalData/views.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:15:53
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# /content/employee_database/PersonalData/views.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:15:57
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# [18/Mar/2023 19:15:58] "GET /employee/create/ HTTP/1.1" 200 2622
# Internal Server Error: /employee/create/
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/django/core/handlers/exception.py", line 56, in inner
#     response = get_response(request)
#   File "/usr/local/lib/python3.9/dist-packages/django/core/handlers/base.py", line 197, in _get_response
#     response = wrapped_callback(request, *callback_args, **callback_kwargs)
#   File "/content/employee_database/PersonalData/views.py", line 39, in employee_create
#     form.save()
#   File "/content/employee_database/PersonalData/forms.py", line 29, in save
#     emergency_contact = self.cleaned_data['emergency_contact']
# KeyError: 'emergency_contact'
# [18/Mar/2023 19:16:28] "POST /employee/create/ HTTP/1.1" 500 77096
# /content/employee_database/PersonalData/views.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:16:52
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# [18/Mar/2023 19:33:29] "GET /employee/create/ HTTP/1.1" 200 2622
# Internal Server Error: /employee/create/
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/django/core/handlers/exception.py", line 56, in inner
#     response = get_response(request)
#   File "/usr/local/lib/python3.9/dist-packages/django/core/handlers/base.py", line 197, in _get_response
#     response = wrapped_callback(request, *callback_args, **callback_kwargs)
#   File "/content/employee_database/PersonalData/views.py", line 39, in employee_create
#     form.save()
#   File "/content/employee_database/PersonalData/forms.py", line 29, in save
#     emergency_contact = self.cleaned_data['emergency_contact']
# KeyError: 'emergency_contact'
# [18/Mar/2023 19:33:56] "POST /employee/create/ HTTP/1.1" 500 77101
# /content/employee_database/PersonalData/forms.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:34:13
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# /content/employee_database/PersonalData/forms.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:34:18
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# /content/employee_database/PersonalData/forms.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:34:32
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# /content/employee_database/PersonalData/forms.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:35:28
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# /content/employee_database/PersonalData/forms.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:35:34
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# /content/employee_database/PersonalData/forms.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:35:36
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# [18/Mar/2023 19:35:39] "GET /employee/create/ HTTP/1.1" 200 2622
# [18/Mar/2023 19:35:43] "GET /employee/create/ HTTP/1.1" 200 2622
# Internal Server Error: /employee/create/
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/django/core/handlers/exception.py", line 56, in inner
#     response = get_response(request)
#   File "/usr/local/lib/python3.9/dist-packages/django/core/handlers/base.py", line 197, in _get_response
#     response = wrapped_callback(request, *callback_args, **callback_kwargs)
#   File "/content/employee_database/PersonalData/views.py", line 39, in employee_create
#     form.save()
#   File "/content/employee_database/PersonalData/forms.py", line 29, in save
#     emergency_contact = self.cleaned_data['emergency_contact-0']
# KeyError: 'emergency_contact-0'
# [18/Mar/2023 19:36:08] "POST /employee/create/ HTTP/1.1" 500 77119
# /content/employee_database/PersonalData/forms.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:37:10
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# /content/employee_database/PersonalData/forms.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# Exception in thread django-main-thread:
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.9/threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/django/utils/autoreload.py", line 64, in wrapper
#     fn(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/django/core/management/commands/runserver.py", line 134, in inner_run
#     self.check(display_num_errors=True)
#   File "/usr/local/lib/python3.9/dist-packages/django/core/management/base.py", line 475, in check
#     all_issues = checks.run_checks(
#   File "/usr/local/lib/python3.9/dist-packages/django/core/checks/registry.py", line 88, in run_checks
#     new_errors = check(app_configs=app_configs, databases=databases)
#   File "/usr/local/lib/python3.9/dist-packages/django/core/checks/urls.py", line 14, in check_url_config
#     return check_resolver(resolver)
#   File "/usr/local/lib/python3.9/dist-packages/django/core/checks/urls.py", line 24, in check_resolver
#     return check_method()
#   File "/usr/local/lib/python3.9/dist-packages/django/urls/resolvers.py", line 494, in check
#     for pattern in self.url_patterns:
#   File "/usr/local/lib/python3.9/dist-packages/django/utils/functional.py", line 57, in __get__
#     res = instance.__dict__[self.name] = self.func(instance)
#   File "/usr/local/lib/python3.9/dist-packages/django/urls/resolvers.py", line 715, in url_patterns
#     patterns = getattr(self.urlconf_module, "urlpatterns", self.urlconf_module)
#   File "/usr/local/lib/python3.9/dist-packages/django/utils/functional.py", line 57, in __get__
#     res = instance.__dict__[self.name] = self.func(instance)
#   File "/usr/local/lib/python3.9/dist-packages/django/urls/resolvers.py", line 708, in urlconf_module
#     return import_module(self.urlconf_name)
#   File "/usr/lib/python3.9/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/content/employee_database/employee_database/urls.py", line 18, in <module>
#     from PersonalData.views import employee_create
#   File "/content/employee_database/PersonalData/views.py", line 3, in <module>
#     from .forms import EmployeeForm
#   File "/content/employee_database/PersonalData/forms.py", line 39
#     contact_instance.save()
#                            ^
# IndentationError: unindent does not match any outer indentation level
# /content/employee_database/PersonalData/forms.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:37:23
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# /content/employee_database/PersonalData/forms.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:37:38
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# /content/employee_database/PersonalData/forms.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:37:43
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# Internal Server Error: /employee/create/
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/django/core/handlers/exception.py", line 56, in inner
#     response = get_response(request)
#   File "/usr/local/lib/python3.9/dist-packages/django/core/handlers/base.py", line 197, in _get_response
#     response = wrapped_callback(request, *callback_args, **callback_kwargs)
#   File "/content/employee_database/PersonalData/views.py", line 39, in employee_create
#     form.save()
#   File "/content/employee_database/PersonalData/forms.py", line 29, in save
#     emergency_contact = self.cleaned_data['emergency_contact-0']
# KeyError: 'emergency_contact-0'
# [18/Mar/2023 19:37:44] "POST /employee/create/ HTTP/1.1" 500 76905
# [18/Mar/2023 19:37:48] "GET /employee/create/ HTTP/1.1" 200 2622
# Internal Server Error: /employee/create/
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/django/core/handlers/exception.py", line 56, in inner
#     response = get_response(request)
#   File "/usr/local/lib/python3.9/dist-packages/django/core/handlers/base.py", line 197, in _get_response
#     response = wrapped_callback(request, *callback_args, **callback_kwargs)
#   File "/content/employee_database/PersonalData/views.py", line 39, in employee_create
#     form.save()
#   File "/content/employee_database/PersonalData/forms.py", line 29, in save
#     emergency_contact = self.cleaned_data['emergency_contact-0']
# KeyError: 'emergency_contact-0'
# [18/Mar/2023 19:38:15] "POST /employee/create/ HTTP/1.1" 500 76895
# /content/employee_database/PersonalData/forms.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:38:24
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# /content/employee_database/PersonalData/forms.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:38:28
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# [18/Mar/2023 19:38:32] "GET /employee/create/ HTTP/1.1" 200 2622
# Internal Server Error: /employee/create/
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/django/core/handlers/exception.py", line 56, in inner
#     response = get_response(request)
#   File "/usr/local/lib/python3.9/dist-packages/django/core/handlers/base.py", line 197, in _get_response
#     response = wrapped_callback(request, *callback_args, **callback_kwargs)
#   File "/content/employee_database/PersonalData/views.py", line 39, in employee_create
#     form.save()
#   File "/content/employee_database/PersonalData/forms.py", line 29, in save
#     emergency_contact = self.cleaned_data['emergency_contact']
# KeyError: 'emergency_contact'
# [18/Mar/2023 19:38:54] "POST /employee/create/ HTTP/1.1" 500 76882
# /content/employee_database/PersonalData/forms.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:39:09
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# /content/employee_database/PersonalData/models.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:39:24
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# /content/employee_database/PersonalData/models.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:45:28
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# /content/employee_database/PersonalData/models.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:45:37
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# /content/employee_database/PersonalData/models.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 19:45:42
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.
# /content/employee_database/PersonalData/models.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 18, 2023 - 20:36:27
# Django version 4.1.7, using settings 'employee_database.settings'
# Starting development server at http://127.0.0.1:80/
# Quit the server with CONTROL-C.

# %%
# !zip employee_database
# Out:
# zip error: Nothing to do! (employee_database.zip)
